# %% [markdown]
# # Домашнее задание 2. Извлечение коллокаций + NER
#
# Выберите корпус отзывов на товары одной из категорий Amazon:
# http://jmcauley.ucsd.edu/data/amazon/

# %% [markdown]
# Допустим, что вам нужно подготовить аналитический отчет по этим отзывам — например, для производителя нового продукта этой категории. Для этого будем искать упоминания товаров в отзывах (будем считать их NE). Учтите, что упоминание может выглядеть не только как "Iphone 10", но и как "модель", "телефон" и т.п.
#
# **Важное замечание**: в задании приводятся примеры решений, вы можете их использовать!
#
# 1. (3 балла) Предложите 3 способа найти упоминания товаров в отзывах.
# Например, использовать bootstrapping: составить шаблоны вида "холодильник XXX", найти все соответствующие n-граммы и выделить из них называние товара.
# Могут помочь заголовки и дополнительные данные с Amazon (Metadata [здесь](https://nijianmo.github.io/amazon/index.html))
# Какие данные необходимы для каждого из способов? Какие есть достоинства/недостатки?

# %% [markdown]
# 1) Bootstrapping. Посмотреть корпус, вручную выделить контексты, в которых фигурирует название товара. Далее по этим шаблонам выделить все сущности.
#
# Необходимые данные.
# - Корпус
# - Придуманные шаблоны
#
# Достоинства.
# + Можем вручную контролировать результат: добавлять или убирать часть шаблонов
#
# Недостатки.
# - Формат отзывов - свободный, поэтому потенциальных шаблонов может быть бесконечно много, а выделять их придётся долго
# - Название товара может вообще не упоминаться в отзыве и мы не сможем его выделить
# - Смешиваются дескрипторы и NE - название товара
# - Мы заранее не знаем длину NE, но нам надо её задать в шаблоне. Если мы будем искать дескриптор + униграмму, то потеряем часть многих названий. Если будем искать дескриптор + длинную n-грамму, то наберём лишних слов
#
# 2) Вручную составить список возможных названий товаров. Найти для них синонимы с помощью эмбеддинга, используя косинусную близость
#
# Необходимые данные.
# - Корпус/метаданные для составления первоначального списка
# - Эмбеддинг для поиска синонимов
#
# Достоинства.
# + Как и в прошлом пункте, можем добавлять/убирать нужные названия в изначальный список по своему желанию
#
# Недостатки.
# - Данные эмбеддинга могут значительно отличаться от данных корпуса
# - Нужно вручную подбирать порог косинусной близости
# - Нужно придумывать первончальный список названий. Не факт, что наше воображение подскажет наиболее центральные наименования, от которых хорошо найдутся остальные (синонимы)
#
# 3) Извлечь из метаданных название товара - существительное. По корпусу отзывов найти для них синонимы, используя косинусную близость.
#
# Необходимые данные.
# - Корпус
# - Метаданные
# - Векторная модель для поиска синонимов
#
# Достоинства.
# + Извлекаем данные автоматически
# + Все данные актуальны, так как берём их из самого корпуса, а не из внешних моделей или словарей
#
# Недостатки.
# - Необходимо подобрать порог косинусной близости
# - Не извлечем упоминания, далёкие от названия товара

# %% [markdown]
# 2. (2 балла) Реализуйте один из предложенных вами способов.
#
# Примеры в качестве подсказки (можно использовать один из них):
# - написать правила с помощью [natasha/yargy](https://github.com/natasha/yargy)
# - составить мини-словарь сущностей/дескрипторов, расширить с помощью эмбеддингов (например, word2vec)

# %% [markdown]
# Категория: Музыкальные инструменты
#
# Попробую реализовать способ 3

# %%
import json
import gzip
from tqdm import tqdm
import random
from collections import Counter
from gensim.models import Word2Vec
import spacy
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
sw = stopwords.words('english')
sc = spacy.load("en_core_web_sm")

# %%
# загружаем данные 

def parse(path):
    g = gzip.open(path, 'r')
    for l in g:
        yield json.loads(l)
        

data = tuple(tqdm(parse('reviews_Musical_Instruments_5.json.gz')))
# Out:
# 10261it [00:00, 22360.35it/s]

# %%
len(data)
# Out:
# 10261

# %%
data[-11]
# Out:
# {'reviewerID': 'A30J7WQV0ZNRXG',
#  'asin': 'B00JBIVXGC',
#  'reviewerName': 'D. Reinstein "marindavid"',
#  'helpful': [0, 0],
#  'reviewText': 'I had used Elixer strings for several years on both 6 and 12 string guitars. Somehow, I had gravitated over to Martin PB about a year ago (when I acquired a new Martin... Surprise!) I got a set of these strings through the Vine program and chose to try them out on a Gibson Songwriter Studio Deluxe CE RATHER than on a Taylor or Martin. The result is outstanding - So much so, that I am beginning to restring all 7 of my acoustic and acoustic-electric guitars with Elixers again.They are even smoother and easier to play that I remembered them. Of course, these new strings have improved the technology which becomes more and more important to me as my fingers age right along with the rest of my body. The sound is sweet and warm and the Gibson has never sounded better - played plugged-in or unplugged.Elixer definitely still has the edge. Thanks to Bob Taylor and his crew for collaborating on something that benefits all guitar players - no matter what it says on the head stocks of our instruments.',
#  'overall': 5.0,
#  'summary': 'Great On A Gibson, Too!',
#  'unixReviewTime': 1404950400,
#  'reviewTime': '07 10, 2014'}

# %%
# загружаем метаданные
meta = tuple(tqdm(parse('meta_Musical_Instruments.json.gz')))
# Out:
# 120310it [01:06, 1797.65it/s]

# %%
len(meta)
# Out:
# 120310

# %%
meta[0]
# Out:
# {'category': ['Musical Instruments',
#   'Drums & Percussion',
#   'Hand Percussion',
#   'Folk & World',
#   'Latin Percussion',
#   'Guiros'],
#  'tech1': '',
#  'description': ["Cricket Rubbing the spine with the wooden stick up and down motion on its back making cricket chirping like buzzing or sizzling sound. Owl Whistle its back producing lovely high-low sounds. It would produce Owl's sound like 00-oo- hoo-hoo-hoo-hoo-oo-00. These products are 100% natural and handmade by local Thai artisan causing variations in its design and color. * Choose your owl design, either all brown or with black foot. Default is all brown."],
#  'fit': '',
#  'title': 'Wooden Percussion 2 Piece Set of 3 Inch Cricket and Inch Owl',
#  'also_buy': ['B00NP8GYVS', 'B00NP80XMO', 'B00NP8M098'],
#  'tech2': '',
#  'brand': 'WADSUWAN SHOP',
#  'feature': ['Wood percussion',
#   'Owl whistle*',
#   'Includes wooden scraper',
#   'Small 3"',
#   'Age rating: 3+'],
#  'rank': ['>#141,729 in Musical Instruments (See Top 100 in Musical Instruments)',
#   '>#95 in Musical Instruments > Drums & Percussion > Hand Percussion > Folk & World > Latin Percussion > Guiros'],
#  'also_view': [],
#  'main_cat': 'Musical Instruments',
#  'similar_item': '',
#  'date': 'December 2, 2013',
#  'price': '',
#  'asin': '0000989983',
#  'imageURL': ['https://images-na.ssl-images-amazon.com/images/I/41uxJnTyg6L._SS40_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/31BuZbUjglL._SS40_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/41O74Alxf5L._SS40_.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/41s43H5H2tL._SS40_.jpg'],
#  'imageURLHighRes': ['https://images-na.ssl-images-amazon.com/images/I/41uxJnTyg6L.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/31BuZbUjglL.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/41O74Alxf5L.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/41s43H5H2tL.jpg']}

# %%
# tqdm показал, что полный набор метаданных будет обрабатываться час. чтобы не тратить время, сделаем рандомную выборку
sample = random.sample(meta, 10000)

nouns = []

for item in tqdm(sample):
    title = item['title']
    parsed = sc(title)
    for token in parsed:
        if token.pos_ == 'NOUN':
            nouns.append(token.lemma_)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 10000/10000 [05:03<00:00, 32.98it/s]

# %%
cnt = Counter(nouns)

# %%
cnt.most_common(100)
# Out:
# [('inch', 443),
#  ('amp', 186),
#  ('case', 159),
#  ('pack', 143),
#  ('usb', 130),
#  ('microphone', 128),
#  ('foot', 118),
#  ('cable', 92),
#  ('size', 83),
#  ('string', 83),
#  ('ft', 81),
#  ('x', 73),
#  ('|', 66),
#  ('dj', 60),
#  ('set', 60),
#  ('g', 58),
#  ('mm', 58),
#  ('style', 50),
#  ('light', 46),
#  ('piece', 44),
#  ('way', 44),
#  ('leather', 39),
#  ('guitar', 39),
#  ('strap', 39),
#  ('planet', 38),
#  ('c', 38),
#  ('pc', 37),
#  ('gold', 36),
#  ('performance', 36),
#  ('cd', 36),
#  ('line', 32),
#  ('hole', 32),
#  ('medium', 31),
#  ('saxophone', 30),
#  ('end', 29),
#  ('sound', 29),
#  ('accessory', 29),
#  ('pair', 27),
#  ('pin', 26),
#  ('effect', 26),
#  ('stand', 25),
#  ('instrument', 25),
#  ('fender', 24),
#  ('stage', 24),
#  ('cm', 23),
#  ('dvd', 23),
#  ('plug', 23),
#  ('system', 22),
#  ('color', 22),
#  ('boss', 21),
#  ('silver', 21),
#  ('pick', 21),
#  ('a', 21),
#  ('audio', 21),
#  ('abs', 21),
#  ('pro', 21),
#  ('sd', 20),
#  ('wheel', 20),
#  ('unit', 20),
#  ('volume', 20),
#  ('tuning', 20),
#  ('clip', 20),
#  ('o', 19),
#  ('type', 19),
#  ('machine', 19),
#  ('pedal', 19),
#  ('headset', 19),
#  ('-', 19),
#  ('drumstick', 18),
#  ('b', 18),
#  ('year', 17),
#  ('flute', 17),
#  ('mixer', 17),
#  ('side', 17),
#  ('ovation', 16),
#  ('key', 16),
#  ('channel', 16),
#  ('led', 16),
#  ('throne', 16),
#  ('head', 16),
#  ('oz', 15),
#  ('#', 15),
#  ('music', 15),
#  ('e', 15),
#  ('t', 15),
#  ('mp3', 15),
#  ('power', 14),
#  ('custom', 14),
#  ('stick', 14),
#  ('epiphone', 14),
#  ('r', 14),
#  ('behringer', 14),
#  ('w/', 13),
#  ('speaker', 13),
#  ('v', 13),
#  ('space', 13),
#  ('nut', 13),
#  ('watt', 13),
#  ('drum', 13),
#  ('ear', 13)]

# %% [markdown]
# Мы получили некоторое количество мусора. Попробуем отфильтровать по длине слова. Плюс удалим inch - это, очевидно, часть характеристики товара, а не его название

# %%
del cnt['inch']

# %%
to_del = []

for word in cnt:
    if len(word) <= 2:
        to_del.append(word)
        
for word in to_del:
    del cnt[word]

# %%
cnt.most_common(100)
# Out:
# [('amp', 186),
#  ('case', 159),
#  ('pack', 143),
#  ('usb', 130),
#  ('microphone', 128),
#  ('foot', 118),
#  ('cable', 92),
#  ('size', 83),
#  ('string', 83),
#  ('set', 60),
#  ('style', 50),
#  ('light', 46),
#  ('piece', 44),
#  ('way', 44),
#  ('leather', 39),
#  ('guitar', 39),
#  ('strap', 39),
#  ('planet', 38),
#  ('gold', 36),
#  ('performance', 36),
#  ('line', 32),
#  ('hole', 32),
#  ('medium', 31),
#  ('saxophone', 30),
#  ('end', 29),
#  ('sound', 29),
#  ('accessory', 29),
#  ('pair', 27),
#  ('pin', 26),
#  ('effect', 26),
#  ('stand', 25),
#  ('instrument', 25),
#  ('fender', 24),
#  ('stage', 24),
#  ('dvd', 23),
#  ('plug', 23),
#  ('system', 22),
#  ('color', 22),
#  ('boss', 21),
#  ('silver', 21),
#  ('pick', 21),
#  ('audio', 21),
#  ('abs', 21),
#  ('pro', 21),
#  ('wheel', 20),
#  ('unit', 20),
#  ('volume', 20),
#  ('tuning', 20),
#  ('clip', 20),
#  ('type', 19),
#  ('machine', 19),
#  ('pedal', 19),
#  ('headset', 19),
#  ('drumstick', 18),
#  ('year', 17),
#  ('flute', 17),
#  ('mixer', 17),
#  ('side', 17),
#  ('ovation', 16),
#  ('key', 16),
#  ('channel', 16),
#  ('led', 16),
#  ('throne', 16),
#  ('head', 16),
#  ('music', 15),
#  ('mp3', 15),
#  ('power', 14),
#  ('custom', 14),
#  ('stick', 14),
#  ('epiphone', 14),
#  ('behringer', 14),
#  ('speaker', 13),
#  ('space', 13),
#  ('nut', 13),
#  ('watt', 13),
#  ('drum', 13),
#  ('ear', 13),
#  ('clarinet', 13),
#  ('percussion', 13),
#  ('part', 12),
#  ('body', 12),
#  ('model', 12),
#  ('pyle', 12),
#  ('allpart', 12),
#  ('length', 12),
#  ('song', 12),
#  ('seagull', 12),
#  ('note', 11),
#  ('art', 11),
#  ('package', 11),
#  ('lighting', 11),
#  ('replacement', 11),
#  ('bass', 11),
#  ('pearl', 11),
#  ('wire', 11),
#  ('6pc', 11),
#  ('studio', 11),
#  ('nickel', 10),
#  ('dozen', 10),
#  ('clamp', 10)]

# %%
# Так уже лучше

chosen = set([item[0] for item in cnt.most_common(100)])

# %%
corpus = []

for item in tqdm(data):
    text = item['reviewText']
    words = word_tokenize(text)
    words = [word.lower() for word in words if word.isalpha() and word not in sw]
    corpus.append(words)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 10261/10261 [00:25<00:00, 406.14it/s]

# %%
corpus[0]
# Out:
# ['not',
#  'much',
#  'write',
#  'exactly',
#  'supposed',
#  'filters',
#  'pop',
#  'sounds',
#  'recordings',
#  'much',
#  'crisp',
#  'one',
#  'lowest',
#  'prices',
#  'pop',
#  'filters',
#  'amazon',
#  'might',
#  'well',
#  'buy',
#  'honestly',
#  'work',
#  'despite',
#  'pricing']

# %%
model = Word2Vec(sentences=corpus, vector_size=100, window=5, min_count=1, workers=4)

# %%
model.wv.most_similar('guitar', topn=10)
# Out:
# [('electric', 0.9032512903213501),
#  ('acoustic', 0.8921219110488892),
#  ('guitars', 0.8815601468086243),
#  ('mandolin', 0.8618844747543335),
#  ('classical', 0.8593218922615051),
#  ('uke', 0.852906346321106),
#  ('violin', 0.8483079075813293),
#  ('alvarez', 0.843752920627594),
#  ('banjo', 0.8360181450843811),
#  ('strat', 0.8355288505554199)]

# %%
from_model = []


for word in chosen:
    try:
        similar = model.wv.most_similar(word, topn=2)  # не хочется добавлять много
        for sim in similar:
            if sim[0] not in chosen and sc(sim[0])[0].pos_ == 'NOUN' and len(sim[0]) > 2:
                from_model.append(sc(sim[0])[0].lemma_)
    except:  # на случай, если ключа нет в модели
        pass

# %%
len(from_model)
# Out:
# 71

# %%
from_model
# Out:
# ['water',
#  'glue',
#  'gator',
#  'logo',
#  'pedal',
#  'wave',
#  'planet',
#  'condenser',
#  'strap',
#  'rehearsal',
#  'interface',
#  'band',
#  'preamp',
#  'track',
#  'track',
#  'home',
#  'class',
#  'kill',
#  'input',
#  'baritone',
#  'padding',
#  'pocket',
#  'file',
#  'store',
#  'tube',
#  'amp',
#  'bag',
#  'video',
#  'house',
#  'moment',
#  'maintenance',
#  'desk',
#  'butter',
#  'pad',
#  'hole',
#  'swivel',
#  'repair',
#  'business',
#  'tune',
#  'construction',
#  'rubbery',
#  'hofner',
#  'fingertip',
#  'supply',
#  'gibson',
#  'tune',
#  'kit',
#  'device',
#  'interface',
#  'operation',
#  'bottom',
#  'front',
#  'tone',
#  'pick',
#  'extension',
#  'month',
#  'week',
#  'price',
#  'cost',
#  'holder',
#  'pivot',
#  'primary',
#  'keyboard',
#  'mandolin',
#  'pound',
#  'car',
#  'gibson',
#  'interface',
#  'compression',
#  'chorus',
#  'cable']

# %%
complete = chosen | set(from_model)

# %%
len(complete)
# Out:
# 159

# %%
complete
# Out:
# {'6pc',
#  'abs',
#  'accessory',
#  'allpart',
#  'amp',
#  'art',
#  'audio',
#  'bag',
#  'band',
#  'baritone',
#  'bass',
#  'behringer',
#  'body',
#  'boss',
#  'bottom',
#  'business',
#  'butter',
#  'cable',
#  'car',
#  'case',
#  'channel',
#  'chorus',
#  'clamp',
#  'clarinet',
#  'class',
#  'clip',
#  'color',
#  'compression',
#  'condenser',
#  'construction',
#  'cost',
#  'custom',
#  'desk',
#  'device',
#  'dozen',
#  'drum',
#  'drumstick',
#  'dvd',
#  'ear',
#  'effect',
#  'end',
#  'epiphone',
#  'extension',
#  'fender',
#  'file',
#  'fingertip',
#  'flute',
#  'foot',
#  'front',
#  'gator',
#  'gibson',
#  'glue',
#  'gold',
#  'guitar',
#  'head',
#  'headset',
#  'hofner',
#  'holder',
#  'hole',
#  'home',
#  'house',
#  'input',
#  'instrument',
#  'interface',
#  'key',
#  'keyboard',
#  'kill',
#  'kit',
#  'leather',
#  'led',
#  'length',
#  'light',
#  'lighting',
#  'line',
#  'logo',
#  'machine',
#  'maintenance',
#  'mandolin',
#  'medium',
#  'microphone',
#  'mixer',
#  'model',
#  'moment',
#  'month',
#  'mp3',
#  'music',
#  'nickel',
#  'note',
#  'nut',
#  'operation',
#  'ovation',
#  'pack',
#  'package',
#  'pad',
#  'padding',
#  'pair',
#  'part',
#  'pearl',
#  'pedal',
#  'percussion',
#  'performance',
#  'pick',
#  'piece',
#  'pin',
#  'pivot',
#  'planet',
#  'plug',
#  'pocket',
#  'pound',
#  'power',
#  'preamp',
#  'price',
#  'primary',
#  'pro',
#  'pyle',
#  'rehearsal',
#  'repair',
#  'replacement',
#  'rubbery',
#  'saxophone',
#  'seagull',
#  'set',
#  'side',
#  'silver',
#  'size',
#  'song',
#  'sound',
#  'space',
#  'speaker',
#  'stage',
#  'stand',
#  'stick',
#  'store',
#  'strap',
#  'string',
#  'studio',
#  'style',
#  'supply',
#  'swivel',
#  'system',
#  'throne',
#  'tone',
#  'track',
#  'tube',
#  'tune',
#  'tuning',
#  'type',
#  'unit',
#  'usb',
#  'video',
#  'volume',
#  'water',
#  'watt',
#  'wave',
#  'way',
#  'week',
#  'wheel',
#  'wire',
#  'year'}

# %% [markdown]
# Очевидный минус - слишком много характеристик товаров (типа color, size, year). Возможно, метод №2 был бы лучше метода №3: мы бы нашли синонимы только нужных нам существительных, а не всех, встречающихся в заголовках товаров

# %% [markdown]
# 3. (1 балл) Соберите n-граммы с полученными сущностями (NE + левый сосед / NE + правый сосед)

# %%
my_sw = {'the', 'a', 'is', 'this', 'that', 'or', 'to', 'of', 'my', 'was', 'has', 'with', 'like', 'as', 'at', 'for'}
pairs = set()

for sent in sentences:
    for i, word in enumerate(sent):
        if word in complete:
            if i > 0 and sent[i - 1] not in my_sw:
                pairs.add(sent[i - 1] + ' ' + word)
            if i != len(sent) - 1 and sent[i + 1] not in my_sw:
                pairs.add(word + ' ' + sent[i + 1])

# %%
pairs
# Out:
# {'and clarinet',
#  'bottom will',
#  'rubber piece',
#  'side wall',
#  'house feel',
#  'twin tube',
#  'solid desk',
#  'pocket inside',
#  'single light',
#  'model if',
#  'volume control.it',
#  '(which swivel',
#  'pedal strikes',
#  'endless supply',
#  'up tuning',
#  'guitars volume',
#  'stage headphones',
#  'swivel joint',
#  'clip because',
#  'heavy head',
#  'style mandolin',
#  'goth studio',
#  'perfect strap',
#  'year old,',
#  'plastic package',
#  'winder/cutter/bridge pin',
#  'glue rectified',
#  'doing studio',
#  'poor volume',
#  '1970 gibson',
#  'model features',
#  'supply, input',
#  'accurate tuning',
#  'audio racks',
#  'can sound',
#  'through amp',
#  'boss os2',
#  'good price',
#  '335-style case',
#  'guitar type',
#  'pedal though.',
#  'light breakup',
#  'princeton chorus',
#  'fender amp',
#  'it custom',
#  'some tube',
#  'gibson gospel',
#  'pedal selection,',
#  'piece into',
#  'all planet',
#  'octagon hole',
#  'better tune',
#  'tome machine',
#  'old pad',
#  'chorus ...good',
#  'effect here',
#  'included usb',
#  'winder, string',
#  '3 string',
#  'band pratice',
#  'behringer ******thank',
#  'stick when',
#  '6,5,4,3 string',
#  'sound especially',
#  'stick through',
#  'sound "big",',
#  'stand remains',
#  'inexpensive guitar',
#  'studio recording,',
#  'indestructable guitar',
#  'pedal train...',
#  'track digital',
#  'solid case',
#  'volume bump,',
#  'closer. sound',
#  'expert drum',
#  'pick (sorry',
#  'clean instrument',
#  'use usb',
#  'cable so',
#  'stand folds',
#  'last effect',
#  'foot pedal.the',
#  'having tuning',
#  'sound clean',
#  'guitar never',
#  'drum track',
#  'rehearsal rig.',
#  'they set',
#  'behringer one',
#  'pivot so',
#  'clamp out.',
#  'pretty color',
#  'could track',
#  'tune --',
#  'neck strap',
#  'button pedal',
#  'manual clamp',
#  'top/bottom end',
#  'fender telecoustic',
#  'pitched sound',
#  'audio drivers,',
#  'behringer reliability',
#  'strap kicks',
#  'your microphone',
#  'guitar shipped',
#  'univeral clip',
#  'uke head',
#  'key stage',
#  'drive, bass',
#  'speaker wire',
#  'intensity light',
#  'mid way',
#  'playing sound',
#  'beat price',
#  'proper foot',
#  'guitar amps',
#  'size, light',
#  'extra glue',
#  'behringer xm8500.',
#  'coding system',
#  'drum pads,',
#  'channel very',
#  'two boss',
#  'little light',
#  'sound goes,',
#  'end separated',
#  'rock kit',
#  'power up',
#  'sound versus',
#  'way its',
#  'little music',
#  'foot (on',
#  'also part',
#  'normal line',
#  'difficulty tuning',
#  'speaker cable',
#  'quality condenser',
#  'tune anymore,',
#  'kurzweil model',
#  'tone might',
#  'gold (5-10',
#  'cabs, percussion',
#  'file in',
#  'style each.',
#  'found part',
#  'replicate tube',
#  'steel string',
#  'watt (into',
#  'channel switching',
#  'peculiar size',
#  'have type',
#  'then tuning',
#  'band sound',
#  'effect sound.simple',
#  "strap i've",
#  'nanoweb light',
#  'tune these',
#  'base tone',
#  'microphone for"?',
#  'cable really',
#  'thread space',
#  'color (both',
#  '(where cable',
#  'both bass',
#  'cable (included)',
#  'sewing machine',
#  'amp cord',
#  '12s sound',
#  'pro tripod',
#  'agreeable tone',
#  'guitar case...',
#  'small microphone',
#  'sound because',
#  'song &#34;big',
#  'microphone cables,',
#  "fender beginner's",
#  'set well',
#  'pin 1',
#  'epiphone mandolin.',
#  'serious pro',
#  'unit becuase',
#  "didn't sound",
#  'power many',
#  'keyboard player,',
#  'guitar get',
#  'length requirement.',
#  'user interface',
#  'pedal (hof',
#  'light action.',
#  'sound samples',
#  'metal clamp',
#  '$30+ price',
#  'studio monitors.',
#  'clip appear',
#  'amp and',
#  'an epiphone',
#  'fine bag',
#  'tone control,',
#  'boss sd-1,',
#  'sound mimics',
#  'wave picks',
#  'exp16 guitar',
#  'soundblaster amp',
#  'may pick',
#  'clamp arm',
#  'music history!',
#  'built-in string',
#  'desk reaching',
#  'stand still.also,',
#  'first power',
#  'tuning knobs.',
#  'pedal does-',
#  'quality power',
#  'same tube',
#  'lead line',
#  'amp because,',
#  'compression takes',
#  'smallish piece',
#  'condenser type',
#  'front controls.addendum:',
#  'music chain',
#  'delflex guitar',
#  'extra piece',
#  'small pedal',
#  'bass rectangular',
#  "amps' tone",
#  'tube amps.',
#  'rp5 studio',
#  'nice color',
#  'recorded.this unit',
#  'box). behringer',
#  'amp produces.',
#  'guitar top',
#  'bass still',
#  'rhythem track',
#  'benz bass',
#  'stand once',
#  'stand cluttering',
#  'steel-string guitar',
#  'studio work.',
#  'sound longer',
#  'mm pick',
#  'playing music',
#  'bag perfectly.like',
#  'store backing',
#  'quality. price',
#  'holding light',
#  'guitar addict.',
#  'alternatives; strap',
#  'their strap',
#  'their price',
#  'guitar leans',
#  'me, sound',
#  'device. note',
#  'amply volume',
#  'what note',
#  'amp reverb',
#  'no tube',
#  'microphone over',
#  'song consisting',
#  'type enhancements',
#  'batter power',
#  'head loop',
#  'tune well.',
#  'volume constantly.....',
#  'amp already',
#  'unique tone',
#  'guitar (which',
#  'instant power',
#  'guitar workstation.',
#  'another system',
#  'string will',
#  'pick clip',
#  'price keeps',
#  'sounding bass',
#  'metalic, sound',
#  'plug and',
#  'iec power',
#  'floor) stand',
#  'sound bad.',
#  'guitar combos',
#  'most amp',
#  'strat(like) guitar',
#  'channel dirty',
#  'electric string',
#  'broken speaker',
#  'drum mounts,',
#  'guitar audio',
#  'hole edge.',
#  'good tube',
#  'right model',
#  'piece off',
#  'works. clamp',
#  'tip clip',
#  'line tone',
#  'behringer 9v',
#  'watt tube',
#  'holder -',
#  'instrument microphoneor',
#  'music after',
#  'volume increase).',
#  "string isn't",
#  'basic leather',
#  'stand made',
#  'tune sooner',
#  'tuning these',
#  'noise.the price',
#  '&#34;meaty&#34; sound',
#  'bigsby tuning',
#  'sound menu)',
#  'led light,',
#  'tune pretty',
#  'used strap',
#  'sound fidelity.',
#  'desired effect',
#  'custom are',
#  'tone when',
#  'live machine',
#  'then, tune',
#  'full extension',
#  'nice condenser',
#  'into sound',
#  'guitar stay',
#  'in drum',
#  'hosa guitar',
#  'and keyboard',
#  'black guitar',
#  "that's part",
#  '$100 tuning',
#  'hi-hat pedal',
#  'only store',
#  'color screen',
#  'desk and',
#  'kit into',
#  'drum beats.',
#  'guitar shine',
#  'included cable',
#  'bass if',
#  'finding pick',
#  'watt amp,',
#  'boss dd-2/dd-3',
#  'medium gauge',
#  'video purpose.pleasantly',
#  'tune em',
#  'speaker i',
#  'volume boost(3)',
#  'damper pedal',
#  'nicer tone',
#  'extension cabinet.',
#  'great, tune',
#  'effect where',
#  'tone sounds',
#  'normal sound',
#  'recording home',
#  'tube sound.',
#  'machine anyway.',
#  'popular stand',
#  'device through',
#  'snare sound',
#  'similar glue',
#  'supply works',
#  'not strap',
#  'audio amps',
#  'cost (which',
#  'studio mic',
#  'never part',
#  'sound possible.',
#  'unit sucks',
#  'foot controller',
#  'light martin',
#  'behringer mixer,',
#  'channel amp,',
#  'cable fan.',
#  'input 1/4-inch',
#  'in audio',
#  'proper maintenance',
#  'decent mandolin',
#  'audio settings',
#  'cable plugged',
#  'guitar output',
#  'elixir light',
#  'part -',
#  'well. color',
#  'they stick',
#  'z keyboard',
#  'pedal purchases',
#  "guitar beautifully.i've",
#  'guitar strings.....to',
#  'guitar fits.)for',
#  'bullets cost',
#  'live performance',
#  'better tube',
#  'sound range',
#  '&#34;perfect pick',
#  'improved sound',
#  'can tune',
#  'dust bag',
#  'bass just',
#  'bigger strap',
#  'seagull can',
#  'pointy end',
#  'on percussion',
#  'house podiums',
#  'impedance cable',
#  'padding because',
#  'bottom on',
#  'straight stand',
#  'tube screamer',
#  'pedal however,',
#  'guitar f/x',
#  'purchase. way',
#  'pin holding',
#  'improves tuning',
#  'combinations, input',
#  'full sound',
#  'pick so',
#  'channel one',
#  'microphone without',
#  'guitar face',
#  'i end',
#  'dedicated device',
#  'non-oily instrument',
#  'excellent strap',
#  'epic guitar',
#  'running water',
#  'light up.',
#  'cable out.',
#  'guitar onto',
#  'readable. price',
#  'sound cuts',
#  'zippered case',
#  'price vs',
#  'epiphone sheraton',
#  'nut on',
#  '3 dozen',
#  'price fool',
#  'buzzing sound',
#  'audio activity.',
#  'leather straps,',
#  'standard mp3',
#  'e.h. bass',
#  'guitar, set',
#  'ratcheting clip',
#  'some gold',
#  'supply (pignose',
#  'preamp would',
#  "70's fender",
#  'some percussion',
#  'tube pre-amp,',
#  'strap purchase',
#  'ziploc-type bag',
#  'still way',
#  'string quite',
#  'power needs',
#  'replacement tubes',
#  'web.this amp',
#  'gold plating',
#  'file i',
#  'amp will',
#  'wellon stage',
#  'effect chain,',
#  'head without',
#  'pick display',
#  'pick designed',
#  'extruding part',
#  'chorus device.',
#  'music so',
#  'string extended',
#  'music one',
#  'very kit',
#  '2 behringer',
#  'off string',
#  'only stand',
#  '50" bag',
#  'rad strap',
#  'tube voodoo.',
#  'house solution',
#  "studio isn't",
#  'line levels',
#  'phase-shifter sound',
#  'with.this pedal',
#  'system first,',
#  'line videos',
#  'xlr cable',
#  'guitar polish.',
#  'cable back',
#  'their front',
#  'several dozen',
#  'in pro',
#  'school chorus',
#  'could power',
#  'and stand',
#  'strap caught',
#  'new clip',
#  'power without',
#  'key on',
#  'clipping compression',
#  'wood color',
#  'three bass',
#  'first piece',
#  'multiple guitar',
#  'space sitting',
#  'double-x keyboard',
#  'normal planet',
#  'piece plastic',
#  'power cycle',
#  'single head',
#  'sound then',
#  'guitar (strat).',
#  'needed) side',
#  'blues pedal',
#  'doing). bottom',
#  'actual cable',
#  'fleas&#34; tuning',
#  'seagull mini',
#  'correct wire',
#  'unit giving',
#  'drumstick and',
#  'awesome unit',
#  'pedal forward.anyway,',
#  'lasso type',
#  "it's tune",
#  'sound different',
#  'stand where',
#  "beginner's instrument",
#  'other percussion',
#  'practice space',
#  'modulation wheel',
#  'padding,nice front',
#  'hot water',
#  'extendo strap',
#  'long end',
#  'tuning you',
#  'demo video',
#  "string you're",
#  'case because',
#  'sound great!i',
#  'hardwood body',
#  'light mics',
#  'guitar, tone',
#  'sound very,',
#  'price ($300',
#  'size pedal).',
#  'dr. pro',
#  'kit arrived',
#  'string windings',
#  'brief bag',
#  'educational device',
#  'music ingredients',
#  'gibson studio',
#  'but set',
#  'some way',
#  'style solos.',
#  'band out',
#  'audio recording',
#  'audio cables',
#  'strap while',
#  'stage /',
#  'color differences.',
#  'arrived set',
#  'intermediate guitar',
#  'pick punches',
#  'tech bag',
#  'me. light',
#  'amp adapts',
#  'more pedal',
#  'mandolin may',
#  'practice guitar',
#  'sound anywhere',
#  'tweed cable',
#  'tone wicker',
#  'another amp',
#  'end cut',
#  'pound gorilla.',
#  'fender tones.',
#  'distorts way',
#  'picks. medium',
#  'sound recorded,',
#  'body through',
#  'fender player',
#  'music shop)',
#  'price here',
#  'pedal very',
#  'hole (with',
#  'fender princeton',
#  'instrument amp',
#  'during band',
#  'dvd remote,',
#  'fender guitar.',
#  'obvious color',
#  'inexpensive pick',
#  'key in',
#  'studio footprint',
#  'nice part',
#  'bassman model',
#  'guitar work.',
#  'ideal string',
#  'decent boss',
#  'tuning on',
#  'boss since',
#  'line humbucker,',
#  'guitar plug',
#  'guitar perfect',
#  'powerful speaker',
#  'power slinkys',
#  'audio recorder.',
#  'stand setup.',
#  'everywhere guitar',
#  'pages).this music',
#  'pick again',
#  'style body',
#  'amps, instrument',
#  'little speaker',
#  'sound into',
#  'nut so',
#  'and compression',
#  'also track',
#  'whole way',
#  'sound sometimes.',
#  'round pick',
#  'vintage tone',
#  'cap side',
#  'mic clip',
#  'tired guitar',
#  'flanger pedal',
#  'pocket rather',
#  'grade microphone',
#  'guitar pics',
#  'any holder',
#  'studio microphone.',
#  'about tuning',
#  'part never',
#  'light strings,',
#  'cable fitted',
#  'guitar rocks.',
#  'input if',
#  'guitar, sound',
#  'guitar in',
#  'unit rendering',
#  'set amounts',
#  'jazz tone',
#  'respectable bass',
#  'piece (except',
#  'volume swells,',
#  'aficionado guitar',
#  'bass mode,',
#  'usb printer',
#  'warm, sound',
#  'year old.',
#  'end extension',
#  "acoustic's head",
#  'higher end',
#  'usb device',
#  'hofner "violin"',
#  'slot-head guitar',
#  'similar strap',
#  'video editor,',
#  "i'll pick",
#  'unit on',
#  'tune up,',
#  'bottom end',
#  'extra end',
#  'guitar lesson',
#  'price hands',
#  'plug your',
#  'fender 250',
#  'wire snips',
#  'string itself,',
#  'heavy-duty stand',
#  'stiff pick',
#  'stand you',
#  'sponge holder',
#  'amp cable',
#  'guitar company',
#  "band's primary",
#  'saturated sound',
#  'head hurt.the',
#  'tube any',
#  'cable without',
#  'ibanez guitar',
#  "fender 9's,",
#  'cable barely',
#  'home when',
#  'nicely. set',
#  'an accessory',
#  'sound hole.',
#  'amp loves',
#  '1963 gibson',
#  'way around!',
#  'cost vs',
#  'head on.',
#  'small part',
#  'bottom side',
#  'silver classical',
#  '2i2 interface',
#  'device permits',
#  'actual body',
#  'quality music',
#  'high-end condenser',
#  'end distort',
#  'boss makes',
#  'decent cable',
#  'mini plug',
#  'strap can',
#  'great amp',
#  'are. guitar',
#  'back lighting',
#  'leather wherever',
#  'guitar anyway.',
#  'guitar effect.',
#  'boss tu-3,',
#  'rubbery grip',
#  'their guitar',
#  'actual studio',
#  'swivel design',
#  'sound really',
#  'system and',
#  'amp (upgrading',
#  'string cleaners',
#  'line up',
#  'tone adjustments.',
#  'boss gt-10',
#  'end resonance',
#  "musician's store",
#  'head very',
#  'nice... sound',
#  'excellent stand',
#  'sound improvement',
#  'type on',
#  'battery cost',
#  'draws power',
#  'your unit',
#  'line just',
#  'tuning fork',
#  'pick notes',
#  'relaxing guitar',
#  "drum mic's",
#  'channel two.the',
#  'package getting',
#  'pickup wire',
#  'pignose amp',
#  'longer power',
#  'adjustment piece',
#  'clip itself',
#  'head i',
#  'condenser microphones,',
#  'wave pattern',
#  'hole using',
#  'usb jack',
#  'guitar (safely)',
#  'same tuning',
#  'wide replacement',
#  'and nut',
#  'tune since...',
#  'and planet',
#  'up. pair',
#  'female end',
#  'drum finese',
#  'band practice',
#  'male size',
#  'next piece',
#  'string compression',
#  'pivot joint',
#  'pro quality',
#  'warm tube',
#  'traditional style',
#  'bass enhancing',
#  'c1 condenser',
#  'quality pair',
#  'tune (for',
#  'amp emulators.&#34;you',
#  'next year',
#  'keyboard standi',
#  'wire can',
#  '4x10 bass',
#  'particular style',
#  'bass version',
#  'power amp',
#  'type pouch',
#  'an ovation',
#  'maintenance free.',
#  'have strap',
#  'her set',
#  'mexican fender',
#  'padding design',
#  'power options',
#  'sound rich',
#  'leather on',
#  'color choices.',
#  'are way',
#  '75 watt',
#  'guitar pikup',
#  'waves kit',
#  'tune either',
#  '1 usb',
#  'studio setup',
#  'pedal configurations.at',
#  'guitar without',
#  'tuning sensor3.',
#  'latest guitar',
#  'pack straps',
#  'not line',
#  'on microphone',
#  'microphone pre-amp.',
#  'reduce sound',
#  'new tube',
#  'fun pedal',
#  '.inf file',
#  'large end',
#  'amp (less',
#  'power supply.there',
#  'another package',
#  'pin stereo',
#  'ga1 guitar',
#  'way off,',
#  'rolands, sound',
#  'guitar stands,',
#  'nylon strap',
#  'can store',
#  'ac9 power',
#  'pedal an',
#  'rhythm track',
#  'tuning.the price',
#  'bottom dropped',
#  'b string',
#  'power jack',
#  'gibson cloths',
#  'kit pieces',
#  'cost cables.',
#  'fender bass.',
#  'favorite amp',
#  'head piece.',
#  'luxurious price',
#  'tripod. pick',
#  'if sound',
#  'line selector,',
#  'holder --',
#  'desk periodically',
#  'six track',
#  'great, sound',
#  'wire look',
#  'amp sound,',
#  'whole body',
#  'guitar studs.the',
#  'gates sound',
#  'rock/metal/grunge type',
#  'purple pick',
#  'no string',
#  'every guitar',
#  'padding should',
#  'through" guitar',
#  'strap decked',
#  'next set',
#  'volume on',
#  'price offered,',
#  'you end',
#  'price tag.i',
#  'simple interface',
#  'bag ,padding',
#  'and/or plug',
#  'performance when',
#  'metal pedal',
#  "amp wasn't",
#  'guitar band,',
#  '2nd string',
#  'from pedal',
#  'case (other',
#  'dramatic tuning',
#  'size before',
#  'strap buttons.but',
#  'will effect',
#  'angle plug',
#  'space saver.',
#  'remarkable microphone',
#  'device helps',
#  'bell-like tone',
#  'string rock',
#  'set limits',
#  'type guy',
#  'possible sound',
#  'effect laden',
#  'leather leave',
#  'new hole',
#  'fender line.once',
#  'an input',
#  'set &',
#  'windows side',
#  'string an',
#  'on, sound',
#  'line guitar/bases,',
#  'expensive chorus',
#  'purchase).this light',
#  'condenser mics.',
#  'one set',
#  'cable on',
#  "'mysterious' tuning",
#  'guitar after',
#  'behringer perfect',
#  'leather side',
#  'supply takes',
#  'guitar cable',
#  'thin line',
#  'stand held',
#  'power grip',
#  'sound vs',
#  'here.schaller strap',
#  'pad from',
#  'got power',
#  'bad pair',
#  'bass gear:',
#  'moment i',
#  'guitar ditto',
#  "it's size",
#  'sound smooth',
#  'guitar gadget.',
#  'string broke',
#  'stage where',
#  ',the hole',
#  '[...] tune',
#  'ok. price',
#  'each set',
#  'audio interface',
#  'way better.',
#  'new model',
#  'vertical piece',
#  'external mixer',
#  'power off',
#  'preamp supports',
#  'distorted tone',
#  'bottom pad,',
#  'nice medium',
#  'pedal would',
#  'noisy music',
#  'ear buds,',
#  'beautiful tone',
#  'jack. speaker',
#  'equipped guitar',
#  'tone adjustment',
#  'useon stage',
#  'solid stand',
#  'house strumming',
#  'soulful tone',
#  'stand forward,',
#  'still plug',
#  'behringer guitar',
#  'usb ports.',
#  'loop track',
#  'fun...the volume',
#  'fender twin...wow,',
#  'sound louder',
#  'instrument nothing',
#  'sound loudly.',
#  "case it's",
#  'base microphone',
#  'volume knob',
#  'head -',
#  'epiphone lp',
#  'glue smell',
#  'strap dislodged,',
#  'string (in',
#  'me guitar',
#  'hotdog style',
#  'ease string',
#  'audio video.',
#  'notch case',
#  'expensive set',
#  'amp ought',
#  'am tuning',
#  'band now',
#  'round sound',
#  'tone belt',
#  'constructed stand',
#  'hot amp',
#  'pearl inlay.the',
#  'similar pro',
#  'heavy guitar',
#  'guitar case.you',
#  'light went',
#  'splitter cable',
#  'identical tuning',
#  'bag within',
#  '"on" light',
#  'sound harsh',
#  'light string.these',
#  'true power',
#  'string instrument,',
#  'finest piece',
#  'you color',
#  'sound tremendously',
#  'pedal gives',
#  'xlr track',
#  'mechanical strap',
#  'supply mounts',
#  'string sufficiently',
#  'side into',
#  'prefer cable',
#  'practice, tuning',
#  'direct guitar',
#  'end design',
#  ...}

# %%
trigrams = set()

for sent in sentences:
    for i, word in enumerate(sent):
        if word in complete:
            if i > 1 and sent[i - 1] not in my_sw and sent[i - 2] not in my_sw:
                trigrams.add(" ".join(sent[i - 2:i + 1]))
            if i > 0 and i != len(sent) - 1 and sent[i + 1] not in my_sw and sent[i - 1] not in my_sw:
                trigrams.add(" ".join(sent[i - 1:i + 2]))
            if i < len(sent) - 2 and sent[i + 1] not in my_sw and sent[i + 2] not in my_sw:
                trigrams.add(" ".join(sent[i:i + 3]))

# %%
trigrams
# Out:
# {'surround sound option.',
#  'forward in sound',
#  'boss pedal tuners).',
#  'fold up stand',
#  'fender amps, and',
#  'guitar polish (already',
#  'and condenser microphones.here',
#  'hours in guitar',
#  'guitar caseto store',
#  "further, it's class",
#  'plus drum and',
#  'tone they are',
#  'chorus which can',
#  'medium sized venue.',
#  'usb cable (mini',
#  'acoustic guitar quick',
#  "sunburst color (it's",
#  'guitar and their',
#  '&#34;tinny&#34;.i should note',
#  'tube amp should',
#  'set screw allows',
#  'color differences. then',
#  '"these strings sound',
#  'ball type mic',
#  'effective akai keyboard',
#  'bag pocket and',
#  'power level. i',
#  'note and have',
#  '&#34; and set',
#  'guitar strap button.',
#  'no guitar effects',
#  '100 watt amp.',
#  'guitars and amp',
#  'tone wicker muff',
#  'pedal can overdrive',
#  'studio deluxe plustopfender',
#  'price for. it',
#  'head stock fits',
#  'general guitar work,',
#  "guitar's. two fender",
#  'these strings...they sound',
#  'style head and',
#  'head you can',
#  'your guitar without',
#  'super light gauge',
#  'store but 3',
#  'nearly pocket change!',
#  'cable i used',
#  'sound tinny through',
#  'it will tune',
#  'string tension feels',
#  'took home and',
#  'head and these',
#  'local music chain',
#  'section 50" bag',
#  'based on video',
#  'tuning head side',
#  'small rehearsal/practice type',
#  'song i am',
#  'ii electric guitar',
#  'plug and jack',
#  'points (where cable',
#  'many planet waves',
#  'strap long ,but',
#  'behringer mixer board',
#  'on every music',
#  'reduce cable "spaghetti',
#  'used to.the bottom',
#  'chorus instead. it',
#  'these unique guitar',
#  'tube amp modeler.only',
#  'tube condenser microphone',
#  '70 watt rating,',
#  'amp (as long',
#  'microphone before home',
#  "home studio. i've",
#  'mic stand (using',
#  'drum beats. it',
#  'good musical ear',
#  'best sound within',
#  'it may cost',
#  'great, its set',
#  'guitar and resonator',
#  'want 90% sound',
#  'thermometer.the whole house',
#  'musical instrument gear',
#  'solid-metal music stand',
#  'and sturdy stand',
#  'bass on guitar',
#  'supply available. it',
#  "2100's, 1 behringer",
#  'end condenser mics',
#  'stand will not',
#  'pattern condenser mic.',
#  'felt way too',
#  'power chords (root-5th',
#  'martin extra light',
#  '6 string version',
#  'usb interface. there',
#  'reasonably priced device',
#  'pick and instrument.',
#  'band eq, ehx',
#  'from fender and',
#  "it's fender reliable",
#  'certain strap other',
#  'power supply too?',
#  'water will extend',
#  'planet waves which',
#  'pick someday, but',
#  'and light use',
#  'stage and i',
#  'right tone ...',
#  'guitar playing. i',
#  'folding piece covered',
#  'foot usb printer',
#  'clamp but they',
#  'guitar and polished',
#  'gauge string (e.g.',
#  "tuning peg. you'll",
#  'front strap mount',
#  'steel string guitars,',
#  'leather strap. i',
#  'cable would do',
#  'rock! expansion kit',
#  'small, unobtrusive size',
#  'tube amp, wanted',
#  'bag works perfectly',
#  'handlebar padding and',
#  'mixer i am',
#  'end (my fender',
#  '-when guitars cost',
#  'screaming guitar but',
#  'fab echo pedal',
#  'drum head from',
#  'record both input',
#  'lifelong-use stand instead',
#  'searching audio interfaces.',
#  'blue led power',
#  'very distinct tone',
#  'and violin bass',
#  'other amps sound',
#  'way over other',
#  "set because i've",
#  '10 hole diatonic',
#  'isolate power and',
#  'black cable does,',
#  "pocket wasn't completely",
#  'sized pocket where',
#  'extra guitar around',
#  'simple chorus effect',
#  'house everything securely.',
#  'usb interface. it',
#  'an end user,',
#  'cost more, i',
#  'they sound good',
#  'up pedalboard space',
#  'distortion pedal would.however,',
#  'tube amps i',
#  'electric guitar, bass',
#  'studio and home.',
#  'lasting guitar strings.',
#  'guitar in order',
#  'light weight. do',
#  'size and adjustable',
#  'way it sounded.',
#  'guitar straps are',
#  'sound reinforcement equipment.',
#  'delay and chorus',
#  'microphone (or instrument',
#  'replace all fender',
#  'from gibson j45',
#  'style you guitar',
#  "ball's guitar strap",
#  'instrument so they',
#  'use every week',
#  'bottom and i',
#  '2 folding guitar',
#  'front are raised',
#  'annoying static sound',
#  'sure your stand',
#  'and instrument microphoneor',
#  'brand new guitar',
#  'serious pro grade,',
#  'string winder, strings,',
#  "american standard's, gibson",
#  'i turn guitar',
#  'boss super chorus',
#  'acoustic guitar pickup.',
#  'price he could',
#  'performance on stage',
#  'great price and',
#  'stand over, but',
#  'powered microphone you',
#  'your pick attacks',
#  'tube and when',
#  'old fashion way',
#  'home practice situations.',
#  'bass and just',
#  '"pick attack" sound',
#  'pedal still effects',
#  'bag and just',
#  'amp down, unplug',
#  'just stick right',
#  'stand i figured',
#  'pale red line',
#  'second standard instrument',
#  'tone feel and',
#  "amp i've tried",
#  'overall great set',
#  'into an usb',
#  'amp sounds. after',
#  'steel light accoustic',
#  'thin line from',
#  'tuning each string',
#  'loves fender...only way',
#  'quality foot rests',
#  'must have type',
#  'mikes are color',
#  '(the bag i',
#  'budget power solutions.also',
#  'guitar perfectly still',
#  'job color coding',
#  'way these hooks',
#  'amp rather than',
#  'in sound from',
#  'guitar strap which',
#  '(red light stays',
#  'foot switch are',
#  'simply fantastic piece',
#  'held, its guitar',
#  'are cheap string',
#  'keyboard rig, where',
#  'in sound on',
#  'amp i went',
#  'pro 346.these are',
#  'your audio does',
#  'week since i',
#  'houses your guitar',
#  'leather may start',
#  'i have space',
#  'system and scratched',
#  'sound samples online',
#  'almost any guitar',
#  "price that's right.update:",
#  '- guitar center',
#  'i plug it',
#  'hard rock leather',
#  "'always on' pedal",
#  'bracket part needs',
#  'amp in direct',
#  'in tune should',
#  'effect pedal blows',
#  'one song when',
#  'set up multiples',
#  'drum beats and',
#  'excellent pedal tuner',
#  'wire around which',
#  'stage gigging and',
#  'effects pedal which',
#  'drum machine, sampler,',
#  '- dunlop, planet',
#  'fender mini tone-master',
#  'they sound good,',
#  'work good. way',
#  'strat style headstock.the',
#  'caig deoxit gold',
#  "cable i've ever",
#  'pedal power power',
#  'power level on',
#  'fender amp unit,',
#  'i plug an',
#  'stands, guitar stands,',
#  'mackie mixer but',
#  'on using music',
#  'away from behringer',
#  'planet waves elliptical',
#  'well, but cost',
#  'book pro and',
#  'pedal will eat',
#  '> amp configuration',
#  'electric guitar stand.',
#  'tuning an older',
#  'little tube on',
#  'interface "instantly worked",',
#  'tuning i immediately',
#  'kit would have',
#  'usb microphone. long',
#  'real valuable guitar',
#  'sound almost identical',
#  'guitar i have',
#  'strap anchors, and',
#  'best sound quality',
#  'line tone adjustments.',
#  'bass amp sound',
#  'everyone knows boss',
#  'were already set',
#  'set awhile back',
#  'store through amazon.',
#  'normal channel will',
#  'pro tools i/o',
#  "sound and that's",
#  'microphone since 1970',
#  'thin leather part.',
#  'violin string set',
#  'paul 5 string',
#  'lot more line',
#  'tone when it',
#  'quick change guitar',
#  'bad part (for',
#  'in sound texture',
#  'wild buffalo leather',
#  'cranked tube amp.',
#  'guitar sounds pretty',
#  'guitar pick pocket',
#  'stand upside down,',
#  '"high end" guitar',
#  'tuning 2nd string,',
#  'drum machines, from',
#  "natural sound that's",
#  'tone and flexibility',
#  '440 tuning fork',
#  'socks in case',
#  'using an usb',
#  "don't line up",
#  'small phillips style',
#  "drum mic's mount",
#  'better padding than',
#  'tuning capo which',
#  "space (couldn't be",
#  'worst pedal i',
#  'dual wireless microphone',
#  'really light but',
#  'power supplies just',
#  'price and quality.',
#  'guitar toolkit, you',
#  'bag perfectly.like i',
#  'way smaller than',
#  'whole guitar including',
#  "perfectly. it's usb",
#  'instrument cable, and',
#  'screw head but',
#  'guitar might tip',
#  '18ams2 martin leather',
#  'line outputs, connect',
#  'heart-shaped fender pick.',
#  'light on knobs',
#  'overs. in sound',
#  'note by 1,',
#  'led burning all',
#  'optional foot switch.if',
#  'size pick. they',
#  'size, light in',
#  'home and studio',
#  'combo amp (using',
#  "power supply didn't",
#  'microphone started tipping',
#  'bass amp along',
#  'are light enough',
#  'pedal board. but',
#  'one note below',
#  'polished leather shoe',
#  'awesome stand and',
#  'epiphone site it',
#  'make drum beats',
#  "only pick i've",
#  'standard microphone windscreen',
#  'various guitar styles.',
#  'front though, so',
#  'fender strings, i',
#  'led lights so',
#  'music stands, we',
#  'string attacks, counter',
#  'sound but i',
#  'guitar but have',
#  'tuning stability. plus',
#  'pick while playing',
#  'set up very',
#  'more fingerlike sound',
#  'strung and set',
#  'piece plastic can',
#  'fuzz pedal you',
#  "regular light (haven't",
#  'string and they',
#  'on stage stuff.',
#  'good compression, power',
#  'competitive price (it',
#  'time - way',
#  'stand alone daw',
#  'your sound -',
#  'little fender logo',
#  'sustained note and',
#  'much sound can',
#  'palpated power button.',
#  'more, behringer makes',
#  'set called exl125',
#  'audio energy and',
#  'band now holds',
#  'trs/phone input (for',
#  '& amp sounds.',
#  'keeping your instrument',
#  'gilmour style slap',
#  'other replacement pads',
#  'acoustic guitar player,',
#  'power source then',
#  'string guide. so',
#  'other flashy string',
#  'way and/or take',
#  "tuning precision doesn't",
#  'samson meteor usb',
#  'plug them in',
#  'set and between',
#  'guitar and voice',
#  'standard power supply',
#  'gratuitous usb hub',
#  'price over night?',
#  'and sample track',
#  'good amp i',
#  'side i also',
#  'music store and',
#  '10 guitar picks',
#  'studio monitors, presonus',
#  'same string gauges.i',
#  'on each effect',
#  'balance. brass color',
#  'capo way out',
#  'nice they sound',
#  'few high end',
#  'time.the strap lock',
#  'amp entirely when',
#  "week when i'm",
#  'more pedal than',
#  'four way gives',
#  '(albeit plastic) stand',
#  'power strip, it',
#  'way ahead on',
#  'stick holder works',
#  '-10db pad i',
#  'great sounding guitar',
#  'constructio,looks good..angled end',
#  'fender blues jr',
#  'add another guitar',
#  'tune while using',
#  'tube driven amp',
#  "doesn't stand up",
#  'inch rca plug',
#  'hosa cable does',
#  'bring your tone',
#  'tube screamer than',
#  'squarely in front',
#  'any coated string',
#  'accuratemounting clip better',
#  'have pedal though,',
#  'wire lengths, i',
#  'music/mic stand and',
#  'studio recording, small',
#  'end are very',
#  'unit too much.keep',
#  'front strap button',
#  'i could power',
#  'stand adapter. it',
#  'guitar signal, you',
#  'it actually cost',
#  'tuning up. it',
#  'legendary boss dd-7',
#  'nut will loosen.',
#  'power on.i picked',
#  'tune acoustic instruments',
#  'head & tweak',
#  'epiphone lp, it',
#  'new nut and',
#  '"stratocaster string tree',
#  'project studio but',
#  'you ask? tone',
#  "way you can't",
#  'behringer ms16 which',
#  'fender look. i',
#  'supply and not',
#  'string cutter, although',
#  'which achieves input',
#  'each string multiple',
#  'behringer ufo202 interface',
#  'guitar online saves',
#  'fender guitar taken',
#  'ezd1 pop/rock kit',
#  'buzz does sound',
#  'another amp sitting',
#  'stage use and',
#  'match tone very',
#  "'63 fender reverb2)",
#  'guitar case, but',
#  'possesses piano style',
#  'out and set',
#  'class b... warmer',
#  'light clip-on 9',
#  'sound uninspiring if',
#  'another string on',
#  'your local music',
#  'may sound good',
#  'clamp mount. then',
#  'volume fader became',
#  'condenser mic but,',
#  'cranked marshall stage',
#  'one power supply.',
#  'certain light conditions',
#  'knob. normal tone',
#  'enough pickups.the price',
#  'guitar straps i',
#  'week old guitar.',
#  "tube screamers aren't",
#  'acoustic guitar sound,',
#  'planet waves insert',
#  'guitar stand. if',
#  '1 music stand,',
#  'bottom can interfere',
#  'planet waves pro',
#  'working dependable power',
#  'fit your head',
#  '"the guitar touches',
#  'sound quality.very functional',
#  'leather straps) before',
#  'plastic coated cable',
#  'double bass c',
#  'protects your guitar',
#  'have any sound',
#  'soft and rubbery',
#  'gibson app on',
#  'wave picks are',
#  'pick attackdo not',
#  'value box set',
#  'fairly poor tone',
#  'wound string on',
#  'baby taylor guitar',
#  "sound i've been",
#  '1 button foot',
#  'play.the tone editing',
#  'likely pick up',
#  'know what string',
#  'their tuning well,',
#  'better pedal accessories',
#  'radio pro always',
#  'stand and carry',
#  "plug and i'm",
#  'guitar will not',
#  'tube half-stack. it',
#  'tone shaping booster',
#  'plug into this..',
#  'reasonably priced effect',
#  'unobtrusive size w/',
#  'price ranges, (oh',
#  'sansamp bass driver',
#  'will stick your',
#  'low cost means',
#  'cymbalsand set these',
#  "diy'ing).this music light",
#  'head and neck',
#  'pad controller, and',
#  'tune nicely. it',
#  'audio terminology, gain,',
#  'his pocket every',
#  'in tune up',
#  "pedal can't do.",
#  'fender f on',
#  "but i'll stick",
#  'model:skb electric bass',
#  'marshall type growl.',
#  'band come on',
#  'clearly marked pack',
#  'them. great price',
#  'another preferred note',
#  'set up anyway',
#  'transport!! rubber strap',
#  'kit covers all',
#  'planet waves uses',
#  'they sound clear',
#  'them next week',
#  'these strings sound',
#  'tuning possible sooner.pretty',
#  'your lighter body',
#  '(a 1984 pedal',
#  "guitar strap. it's",
#  'dynamic performance microphone,',
#  'case purchased locally.',
#  "wah'o sound when",
#  'price point and',
#  'set up, but',
#  'supply and so',
#  'onespot power supply',
#  'pick finally got',
#  'holds guitar fine',
#  'usb plug on',
#  'gotta plug in',
#  'guitar player going',
#  'its performance on',
#  'response. small, light',
#  'strap in, its',
#  'two fender american',
#  'it can track',
#  'rc-3 loop pedal',
#  'strat type axes,',
#  'and deep tone',
#  'deskadjustable desk microphone',
#  'red led burning',
#  'one xlr track',
#  'situation (one guitar',
#  'ear piercing squeaking',
#  'from another planet',
#  'end you plug',
#  'anon stage my550',
#  'musical instrument stands.',
#  '"burgundy" color one.cfh',
#  'guys using clamp',
#  'classic strap from',
#  'sound and craftsmanship',
#  'string set, 4/4',
#  'way an issue',
#  'guitar strings, custom',
#  'your desk uncluttered.',
#  'sound more professional.',
#  'drill new hole',
#  'serious guitar player.',
#  'we play music',
#  'jj tube go',
#  'worth price hands',
#  'bass sound, smoother',
#  'space onstage and',
#  'tone control and',
#  'string extended scale)',
#  '(not crisp) sound',
#  'that. no gold',
#  'simple foot controland',
#  '15-watt amp will',
#  'tuning these strings',
#  'fender fan but',
#  'analog pedal then',
#  'tie wraps, power',
#  'home 6 months',
#  'after tuning but',
#  'home when recording',
#  'head should both',
#  'packs big sound',
#  'any uke sound',
#  'house feel warmer',
#  'in tune (after',
#  'tone basically remains',
#  'pick open just',
#  '10 foot cable',
#  "logo'd gig bag",
#  'other computer-related audio',
#  'an amp and',
#  'strap works okay',
#  'mixer & mxl',
#  'stage and more',
#  'nylon guitar strap,',
#  'pick around in',
#  'std. telecaster input',
#  'tube feature in',
#  "it's compact size",
#  'space verb.okay i',
#  'clip them all',
#  'boss rc-3 loop',
#  'guitar factory) your',
#  'acoustic guitar all',
#  'suck up tone',
#  'tuning on stage,',
#  '"eureka!" moment from',
#  'individual power supplies.',
#  'price though and',
#  'take up space',
#  'plastic/rubber cable can.',
#  'construction and easy',
#  'track than plain',
#  'steel guitar capo',
#  'set up. dials',
#  'changing guitar strings.',
#  'preamps sound great,',
#  'effect applied (set',
#  'nickel and steel',
#  'practice guitar because',
#  'sound replicate tube',
#  'nice carry case',
#  'and lower lighting',
#  'an easy set',
#  'main acoustic guitar',
#  'professional audio recording',
#  'guitar stand in',
#  'amp will go',
#  'an excellent speaker',
#  'price range i',
#  'power supply connector',
#  'stand but i',
#  'competitive price available.',
#  'wire cutters worked.',
#  'strap through which',
#  'included) are gold',
#  'cable set.i am',
#  'application from home',
#  'distortion pedal engaged',
#  'custom comp already,',
#  'iii- sized pick',
#  'chain dc power',
#  'your amp cuts',
#  'sound so warm',
#  'loose. strap holders',
#  'fairly low price',
#  'an unbelievable price',
#  'tune better and',
#  'settings 9-15 model',
#  'hanging in front',
#  'line are some',
#  'joyo pedal looks',
#  'standby harmonica, key',
#  'pedals actually sound',
#  'zt club amp',
#  'rolled edge music',
#  'sweetwater in case',
#  'wound string notes',
#  'lugging your amp',
#  'switches. bam!! guitar',
#  'on guitar but',
#  'every music store',
#  'overdriven light distortion',
#  'us can color',
#  'power usually requires',
#  'foot controller, i',
#  'via usb midi',
#  'firewire high performance',
#  'preventing 5-10 pound',
#  'way we will',
#  'guitar and these',
#  'an "on stage',
#  'works by guitar',
#  'end up liking.',
#  'tube screamers in',
#  'digital audio workstation.',
#  'rest ensures guitar',
#  "way it's supposed",
#  'pedal works great',
#  'your device through',
#  'use garage band',
#  'practice amp only',
#  'guitar more accessible,',
#  'sound input but',
#  'truly heavy-duty stand',
#  'and you;re set',
#  'low end distorts.',
#  'stage quality amps',
#  'item cost $17.70',
#  'your amp shines',
#  'experience in sound',
#  'be way more',
#  'minor tuning tweaks',
#  'boss lo sabe',
#  'furman pedal board',
#  'work making music',
#  '1st. they stick',
#  'break way too',
#  'leather strap i',
#  'one usb cord.',
#  'standing here tuning',
#  'can store it',
#  "more i'll stick",
#  'only cable i',
#  'daisy chain cable',
#  'unit means that,',
#  'old style not',
#  'bag but it',
#  'real tone possible,',
#  'bottom part (that',
#  'reasonably water proof,',
#  'size and keeps',
#  'stand 3 feet',
#  'custom years ago,',
#  'guitar perfectly spaced',
#  'most competitive price',
#  'if your power',
#  'behringer and danelectro',
#  'case ukuleles. good',
#  'home and i',
#  'guitar quality. also,',
#  "time you'll end",
#  '2x10 bass combo',
#  'strap i realized',
#  'an excellent usb',
#  'laser power output,',
#  'nearly inaudible.did boss',
#  'professional grade stand',
#  'and case are',
#  'guitar retaining mechanism',
#  'any glue in',
#  'zipper.3. construction seems',
#  'way i had',
#  'nut really tight.',
#  'speed string changes.',
#  'case you lose',
#  'music since 1980.',
#  'boost volume but',
#  'store and these',
#  'amp plus reverb',
#  'great....the stock tube',
#  'nut width guitars',
#  'wah pedal which',
#  'in his guitar',
#  'price nobody should',
#  '1/8" power connections,',
#  '4 track ability',
#  "unit becuase it's",
#  'thick plastic pedal',
#  'space on yourpedalboard...',
#  'place your guitar',
#  'matter which type',
#  "forever.i'll probably stick",
#  'does sound more',
#  'sound and start',
#  'you lose tone',
#  'being in front',
#  'well.on stage stands',
#  'every stringed instrument',
#  'and guitar looks',
#  'stage pianoand aroland',
#  'on stage without',
#  'most durable power',
#  'epiphone dot custom,',
#  'no pedal can',
#  'good wood guitar',
#  'guitar picks, it',
#  'own crossover cable',
#  'low volume and',
#  'length (if any)',
#  'tune very solidly',
#  'more power on',
#  'cables stand up',
#  'strap may not',
#  'metal guitar riff',
#  'strap button/end bolt',
#  'sound (think motown.)',
#  'foot piece, weighted',
#  "volume on. it's",
#  'size and fit',
#  'most part and',
#  'alone!!!!! no guitar',
#  'adjustable gain, volume',
#  'pedal sounds more',
#  'pedal sold out',
#  'stick while playing.',
#  'strap looks better',
#  '5th bass pick',
#  'gimmick. great pocket',
#  'pedal do make',
#  "watt amp, that's",
#  'good quality studio',
#  'pick and tuner',
#  'band and recording',
#  'strap i will',
#  'close)guitars used: fender',
#  'price may be',
#  'just ordinary tone',
#  'true 2 channel',
#  'drum lines and',
#  'tune after clamping',
#  'but your guitar',
#  'phantom power button',
#  'guitar i pick',
#  'give planet waves',
#  'guitar picks, tuner,',
#  'accurately tune and',
#  'boost comp sound',
#  'condenser type mic',
#  'sound weird and',
#  'bass side and',
#  'speaker cabinets are',
#  'guitar maintenance kits',
#  "fender's /schaller's gold",
#  'audio versatility. i',
#  'mandolin and guitar,',
#  'price you cannot',
#  'slide guitar on',
#  'cs-3 compression sustainer),',
#  'these are condenser',
#  'in tune each',
#  'boss compressor/sustainer. it',
#  'were medium according',
#  'great acoustic sound',
#  'compatible fender amp',
#  'itd will pick',
#  'get good sound',
#  'power other pedals,',
#  'instrument in... lifting',
#  'lab pedal power',
#  'newer fender stratocasters',
#  'gold tone ones',
#  'bottom material along',
#  'older style planet',
#  'very light touch.',
#  'be set aside',
#  'fender champ x2',
#  'dozen other factors',
#  'sound good. perfect',
#  'green overdrive pedal',
#  'reverb effect performed',
#  'over compressed guitar',
#  'kit sound very',
#  'behringer pedals i',
#  'are light plastic,',
#  'those oasis water',
#  "boss hater (i'm",
#  'fast track pro',
#  'extension guitar cord).',
#  'studio projects c1',
#  'head broke off.',
#  'case. neither guitar',
#  'in home multitrack',
#  'behringer stomp box',
#  'an actual guitar',
#  'ratcheted clip and',
#  'clip on sensor',
#  'fender speaker in',
#  'color gives it',
#  'heavier set than',
#  'then your mandolin',
#  'lower price and',
#  'medium jumbo frets',
#  'and tube amp.different',
#  'board and amp',
#  'construction and mechanical',
#  "unit in it's",
#  'mandolin strap i',
#  'more expensive gibson',
#  'sound and after',
#  'bit.highly recommended!cfhevaluation unit',
#  'series all tube',
#  'about every guitar',
#  'time, improves tuning',
#  'about fender acoustic',
#  'other audio source.',
#  'jacks are gold',
#  'control foot pedal',
#  'bass (at least',
#  'chorus are also',
#  'price and took',
#  'strap slip easily,',
#  'button amp channel',
#  'these, they sound',
#  'enough quality sound',
#  'fender amps and',
#  'music store but',
#  'much "bigger" sound',
#  'audio quality strikes',
#  'every pedal numbered',
#  'fender stratocastor.the only',
#  'not leather but',
#  "body base, it's",
#  'amp setup. i',
#  'anyway). epiphone really',
#  'pedal gets me',
#  'max input volume,',
#  'thin pick and',
#  'seagull s6. however,',
#  'tune so i',
#  'sound better but',
#  'and amp tone',
#  'note mode seems',
#  'bass and mid-range',
#  'xcg4 tubular guitar',
#  'on price i',
#  'power cord (standard',
#  'microphone feedback effect.the',
#  'very fair price',
#  'thing. either way',
#  'note into it',
#  'bass and treble,',
#  'power cable)(3) simple',
#  "cable haha. it's",
#  'boss tu-3 tuner',
#  'pedal will suddenly',
#  'collapsible stand which',
#  'metalheads...this amp probably',
#  'tone loss. simple,',
#  'no external power',
#  'flimsy pedal but',
#  'recording band rehearsals.',
#  'and light it',
#  'tubular construction in',
#  'music - not',
#  'cable and purchase',
#  'pedal you could',
#  'use clip on',
#  'not clip and',
#  "bag that's about",
#  'calibrated studio monitors,',
#  'strings. light guage',
#  'down and pick',
#  'combine tube and',
#  'stick on amp,',
#  'old fender american.',
#  'cost no more',
#  'have another set',
#  'stage where i',
#  'device :-)great unit.',
#  'power adapters (make',
#  'tone and help',
#  ...}

# %% [markdown]
# 4. (3 балла) Ранжируйте n-граммы с помощью 3 коллокационных метрик (t-score, PMI и т.д.). Не забудьте про частотный фильтр / сглаживание.
# Выберите лучший результат (какая метрика  ранжирует выше коллокации, подходящие для отчёта).

# %%
import nltk
from nltk.collocations import *


bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

# %%
# В документации nltk метрики считают через CollocationFinder, который принимает лист с токенами. 
# Возможно, есть способ сразу посчитать метрики для списка n-грамм. 
# Пока, в качестве костыля, просто соединим наши n-граммы в один список

joined_pairs = []
for p in pairs:
    joined_pairs.extend(p.split())
    
joined_trigrams = []
for t in trigrams:
    joined_trigrams.extend(t.split())

# %%
bi_finder = BigramCollocationFinder.from_words(joined_pairs)
tri_finder = TrigramCollocationFinder.from_words(joined_trigrams)
bi_finder.apply_freq_filter(5)
tri_finder.apply_freq_filter(5)

# %%
# PMI

bi_finder.nbest(bigram_measures.pmi, 10)
# Out:
# [('from', 'strap'),
#  ('so', 'string'),
#  ('up', 'sound'),
#  ('fender', 'bag'),
#  ('in', 'bass'),
#  ('style', 'bass'),
#  ('microphone', 'end'),
#  ('and', 'stand'),
#  ('sound', 'supply'),
#  ('performance', 'guitar')]

# %%
tri_finder.nbest(trigram_measures.pmi, 10)
# Out:
# [('guitar', 'planet', 'waves'),
#  ('and', 'planet', 'waves'),
#  ('planet', 'waves', 'guitar'),
#  ('guitar', 'strap', 'locks'),
#  ('power', 'supply', 'and'),
#  ('and', 'clip', 'on'),
#  ('and', 'good', 'price'),
#  ('and', 'electric', 'guitar'),
#  ('acoustic', 'guitar', 'sound'),
#  ('electric', 'guitar', 'sound')]

# %%
# student_t

bi_finder.nbest(bigram_measures.student_t, 10)
# Out:
# [('performance', 'guitar'),
#  ('fender', 'bag'),
#  ('from', 'strap'),
#  ('so', 'string'),
#  ('up', 'sound'),
#  ('style', 'bass'),
#  ('in', 'bass'),
#  ('and', 'stand'),
#  ('sound', 'supply'),
#  ('microphone', 'end')]

# %%
tri_finder.nbest(trigram_measures.student_t, 10)
# Out:
# [('and', 'electric', 'guitar'),
#  ('and', 'tone', 'and'),
#  ('guitar', 'planet', 'waves'),
#  ('and', 'planet', 'waves'),
#  ('guitar', 'strap', 'locks'),
#  ('acoustic', 'guitar', 'sound'),
#  ('on', 'your', 'guitar'),
#  ('and', 'your', 'guitar'),
#  ('planet', 'waves', 'guitar'),
#  ('power', 'supply', 'and')]

# %%
# jaccard

bi_finder.nbest(bigram_measures.jaccard, 10)
# Out:
# [('style', 'bass'),
#  ('and', 'stand'),
#  ('microphone', 'end'),
#  ('sound', 'guitar'),
#  ('set', 'volume'),
#  ('fender', 'bag'),
#  ('from', 'strap'),
#  ('sound', 'sound'),
#  ('tube', 'music'),
#  ('in', 'bass')]

# %%
tri_finder.nbest(trigram_measures.jaccard, 10)
# Out:
# [('guitar', 'planet', 'waves'),
#  ('and', 'planet', 'waves'),
#  ('guitar', 'strap', 'locks'),
#  ('planet', 'waves', 'guitar'),
#  ('on', 'your', 'guitar'),
#  ('and', 'tone', 'and'),
#  ('power', 'supply', 'and'),
#  ('and', 'electric', 'guitar'),
#  ('and', 'clip', 'on'),
#  ('in', 'your', 'guitar')]

# %% [markdown]
# Все три варианат получились так себе. Выглядит так, будто их нужно отфильтровать по частям речи. Я попробовала извлечь n-граммы просто из корпуса (не из списка n-грамм) - у jaccard получались очень хорошие варианты.

# %% [markdown]
# 5. (1 балл) Сгруппируйте полученные коллокации по NE, выведите примеры для 5 товаров.
